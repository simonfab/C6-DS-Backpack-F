# %% [markdown]
# Polarity, in the context of natural language processing (NLP), refers to identifying the sentiment expressed in a piece of text, whether it's positive, negative, or neutral. This concept is crucial in various applications, such as analyzing customer feedback, understanding public sentiment on social media, or even in literature and film reviews analysis.
#
# While spaCy is a powerful library for many NLP tasks, it doesn't natively provide sentiment analysis or polarity detection. For this purpose, we can integrate spaCy with other libraries like TextBlob or VADER (Valence Aware Dictionary and sEntiment Reasoner), which are specifically designed for sentiment analysis.
#
# In this detailed example, I'll demonstrate how to use TextBlob for polarity detection because of its simplicity and effectiveness for educational purposes. TextBlob essentially provides a simple API for common NLP tasks, including sentiment analysis, where the sentiment property returns a namedtuple of the form Sentiment(polarity, subjectivity). The polarity score is a float within the range [-1.0, 1.0], where -1 indicates negative sentiment and +1 indicates positive sentiment.

# %%
# !pip3 install spacy textblob
# !python3 -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in d:\python_files\venvs\venv_ds\lib\site-packages (3.7.4)
# Requirement already satisfied: textblob in d:\python_files\venvs\venv_ds\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: nltk>=3.8 in d:\python_files\venvs\venv_ds\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in d:\python_files\venvs\venv_ds\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in d:\python_files\venvs\venv_ds\lib\site-packages (from nltk>=3.8->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\python_files\venvs\venv_ds\lib\site-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in d:\python_files\venvs\venv_ds\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python_files\venvs\venv_ds\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\python_files\venvs\venv_ds\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python_files\venvs\venv_ds\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\python_files\venvs\venv_ds\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in d:\python_files\venvs\venv_ds\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from jinja2->spacy) (2.1.5)
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Manage App Execution Aliases.

# %%
import spacy
from textblob import TextBlob

# Load the spaCy model
nlp = spacy.load("en_core_web_md")

# %%
def analyze_polarity(text):
    # Preprocess the text with spaCy
    doc = nlp(text)
    
    # Analyze sentiment with TextBlob
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity
    
    return polarity

# %%
text = "I'm so elated this vacation is over, it was fantastic from start to finish."
polarity_score = analyze_polarity(text)

if polarity_score > 0:
    sentiment = 'positive'
elif polarity_score < 0:
    sentiment = 'negative'
else:
    sentiment = 'neutral'

print(f"Text: {text}\nPolarity score: {polarity_score}\nSentiment: {sentiment}")

# -1 to 1
# Out:
# Text: I'm so elated this vacation is over, it was fantastic from start to finish.
# Polarity score: 0.4
# Sentiment: positive

# %% [markdown]
# ## How Polarity Works in the Background
#
# In the background, when a piece of text is analyzed for sentiment:
#
# 1. **Preprocessing:** The text is preprocessed (cleaned and transformed) using NLP techniques to ensure it's in a suitable format for analysis. This might involve spaCy for advanced NLP tasks.
# 2. **Feature Extraction:** The preprocessed text is converted into a numerical format that the model understands.
# 3. **Sentiment Scoring:** The ML model uses the extracted features to calculate a sentiment score based on the patterns it learned during training.
# 4. **Output:** The sentiment score is then mapped to a polarity (positive, negative, neutral) based on predefined thresholds.

# %% [markdown]
# ## Visualizing Polarity and Sentiment Analysis

# %%
# !pip3 install wordcloud
# Out:
# Requirement already satisfied: wordcloud in d:\python_files\venvs\venv_ds\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in d:\python_files\venvs\venv_ds\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in d:\python_files\venvs\venv_ds\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python_files\venvs\venv_ds\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\python_files\venvs\venv_ds\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

from collections import defaultdict

nlp = spacy.load("en_core_web_lg")

# %%
sentences = [
    "I love this product. It works great and has made my life so much easier!",
    "This is the worst movie I have ever seen. Completely disappointed.",
    "What a fantastic experience! Truly memorable and enjoyable.",
    "I'm so sad this vacation is over, it was terrible from start to finish.",
    "The customer service was amazing and very helpful.",
    "The food was bland and I'm unhappy with the service.",
    "Absolutely a joy to use. I'm very satisfied with the performance."
]

# %%
# Initialize dictionaries to hold positive and negative words
positive_words = defaultdict(int)
negative_words = defaultdict(int)

# %%
for sentence in sentences:

    doc = nlp(sentence)
    tokens = [token.lemma_.lower().strip() for token in doc if not token.is_stop and token.is_alpha]
    for token in tokens:
        blob = TextBlob(str(token))

        polarity = blob.sentiment.polarity

        if polarity > 0:
            positive_words[token.lower()] += 1
        elif polarity < 0:
            negative_words[token.lower()] += 1

# %%
pos_wordcloud = WordCloud(width=400, height=200, background_color ='white').generate_from_frequencies(positive_words)
neg_wordcloud = WordCloud(width=400, height=200, background_color ='white').generate_from_frequencies(negative_words)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(pos_wordcloud, interpolation='bilinear')
ax[0].set_title('Positive Words')
ax[0].axis('off')

ax[1].imshow(neg_wordcloud, interpolation='bilinear')
ax[1].set_title('Negative Words')
ax[1].axis('off')

plt.show()

# %%
for sentence in sentences:
    words = sentence.split()

    for word in words:
        blob = TextBlob(word)
        polarity = blob.sentiment.polarity

        if polarity > 0:
            positive_words[word.lower()] += 1
        elif polarity < 0:
            negative_words[word.lower()] += 1

# %%
pos_wordcloud = WordCloud(width=400, height=200, background_color ='white').generate_from_frequencies(positive_words)
neg_wordcloud = WordCloud(width=400, height=200, background_color ='white').generate_from_frequencies(negative_words)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(pos_wordcloud, interpolation='bilinear')
ax[0].set_title('Positive Words')
ax[0].axis('off')

ax[1].imshow(neg_wordcloud, interpolation='bilinear')
ax[1].set_title('Negative Words')
ax[1].axis('off')

plt.show()
